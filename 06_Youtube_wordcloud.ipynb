# %% [markdown]
# # 0 youtube 크롤링 text data 워드클라우드 시각화

# %% [markdown]
# # 1 라이브러리 로드

# %%
import pandas as pd
import seaborn as sns 
import glob
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## 폰트 설정

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux(Colab)
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        import matplotlib as mpl
        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont
        
        font_family = "NanumBarunGothic"
    return font_family

plt.rc("font", family=get_font_family())
plt.rc("axes", unicode_minus=False)

# %% [markdown]
# # 2 데이터 셋 로드

# %%
path = glob.glob('data/*.csv')
path
# Out:
# ['data\\content_total.csv',
#  'data\\review_2021.csv',
#  'data\\review_2022.csv',
#  'data\\total_tweet.csv',
#  'data\\twitter_2021.csv',
#  'data\\twitter_2022.csv',
#  'data\\zepeto_jp_review.csv',
#  'data\\zepeto_kr_review.csv',
#  'data\\zepeto_us_review.csv',
#  'data\\zepeto_youtube.csv']

# %%
custom = pd.read_csv(path[-1], encoding = 'utf-8')
custom
# Out:
#                                                  title  viewcount
# 0    🌹 (재업) 쉬운 제페토 커스텀 강좌 | 컬러피커 필요 없음 | 정지화면으로 설명해...       9000
# 1                                         제페토 커스텀 하는법!      90000
# 2                                  제페토 | 인어공주 대리커스텀 과정       9900
# 3              #제페토#제페토커스텀#ZEPETO 제페토 여캐 커스텀 강좌 20탄/설참       9800
# 4                   [ 제페토 커스텀 ] 고급진 귀여움상 아기캐 커스텀 과정 영상       9700
# ..                                                 ...        ...
# 641                                            제페토놀아보기          2
# 642      제페토를 하면 알아야하는 용어라고? / 제페토 / 제페토아이디 상메 참고 /첫영상          0
# 643                                               그 새끼          0
# 644                                     아윤이의 제페토 추천코디😄          0
# 645                             세임이의 인싸 코디 -제페토 (세임루비)          0
#
# [646 rows x 2 columns]

# %%
custom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 646 entries, 0 to 645
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      646 non-null    object
#  1   viewcount  646 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 10.2+ KB

# %%
custom.sort_values('viewcount', ascending = False)
# Out:
#                                                  title  viewcount
# 21                           제페토 아니에요. 직접 그렸어요. 인증할께요ㅠ     783000
# 27                                       어플보정빼는 중국인 언니     702000
# 37                           아직도 놀이동산 실제로 가니? 제페토 브이로그     673000
# 39   You'll Make the Change + Save the Day (FnF x P...     633000
# 41   /Pibby - You’ll Make The Change (/Pibby VIP Re...     611000
# ..                                                 ...        ...
# 641                                            제페토놀아보기          2
# 642      제페토를 하면 알아야하는 용어라고? / 제페토 / 제페토아이디 상메 참고 /첫영상          0
# 643                                               그 새끼          0
# 644                                     아윤이의 제페토 추천코디😄          0
# 645                             세임이의 인싸 코디 -제페토 (세임루비)          0
#
# [646 rows x 2 columns]

# %%
custom['viewcount']
# Out:
# 0       9000
# 1      90000
# 2       9900
# 3       9800
# 4       9700
#        ...
# 641        2
# 642        0
# 643        0
# 644        0
# 645        0
# Name: viewcount, Length: 646, dtype: int64

# %%
cm = custom[custom['title'].str.contains('커스텀')].sort_values('viewcount', ascending = False)
cm
# Out:
#                                                  title  viewcount
# 164                               🌸벚꽃소녀 커스텀🌸 제페토 얼굴만들기     279000
# 259              [제페토 커스텀]💗눈 커스텀 강좌🎀/ zepeto / 제페토 커스텀     138000
# 274                        [제페토] 제페토 얼굴만들기! 두기 닮은 커스텀~     115000
# 282                            제페토 커스텀 - 도도한 여캐 커스텀 설참     104000
# 283                     ⭐기본으로 커스텀⭐ 제페토 얼굴만들기 (+약간의 수정)     102000
# ..                                                 ...        ...
# 633                                     💙토끼상 커스텀🐰 (설참)         11
# 634  완전예쁜커마를 2분안에 만들수있다고??? +추천 크리템 추천 [제페토] #제페토 #...         10
# 635                                 배드워즈 커스텀으로 버그(?)찾기         10
# 636             [제페토 커스텀] 초간단 제페토 귀여운 여아캐 커스텀❣️ (세로영상)          6
# 639  순백 커스텀/ 팔레트 필요없음/ 출처 남겨주세요/ 제페토 커스텀/ 예쁜 여캐 커스텀...          3
#
# [489 rows x 2 columns]

# %%
cm.describe()
# Out:
#            viewcount
# count     489.000000
# mean     7446.124744
# std     20329.043189
# min         3.000000
# 25%       233.000000
# 50%       887.000000
# 75%      5200.000000
# max    279000.000000

# %%
cm.reset_index(inplace = True)

# %%
cm.reset_index(inplace = True)

# %%
cm
# Out:
#      level_0  index                                              title  \
# 0          0    164                               🌸벚꽃소녀 커스텀🌸 제페토 얼굴만들기
# 1          1    259              [제페토 커스텀]💗눈 커스텀 강좌🎀/ zepeto / 제페토 커스텀
# 2          2    274                        [제페토] 제페토 얼굴만들기! 두기 닮은 커스텀~
# 3          3    282                            제페토 커스텀 - 도도한 여캐 커스텀 설참
# 4          4    283                     ⭐기본으로 커스텀⭐ 제페토 얼굴만들기 (+약간의 수정)
# ..       ...    ...                                                ...
# 484      484    633                                     💙토끼상 커스텀🐰 (설참)
# 485      485    634  완전예쁜커마를 2분안에 만들수있다고??? +추천 크리템 추천 [제페토] #제페토 #...
# 486      486    635                                 배드워즈 커스텀으로 버그(?)찾기
# 487      487    636             [제페토 커스텀] 초간단 제페토 귀여운 여아캐 커스텀❣️ (세로영상)
# 488      488    639  순백 커스텀/ 팔레트 필요없음/ 출처 남겨주세요/ 제페토 커스텀/ 예쁜 여캐 커스텀...
#
#      viewcount
# 0       279000
# 1       138000
# 2       115000
# 3       104000
# 4       102000
# ..         ...
# ...

# %%
cm = cm.drop('index', axis=1)
cm
# Out:
#      level_0                                              title  viewcount
# 0          0                               🌸벚꽃소녀 커스텀🌸 제페토 얼굴만들기     279000
# 1          1              [제페토 커스텀]💗눈 커스텀 강좌🎀/ zepeto / 제페토 커스텀     138000
# 2          2                        [제페토] 제페토 얼굴만들기! 두기 닮은 커스텀~     115000
# 3          3                            제페토 커스텀 - 도도한 여캐 커스텀 설참     104000
# 4          4                     ⭐기본으로 커스텀⭐ 제페토 얼굴만들기 (+약간의 수정)     102000
# ..       ...                                                ...        ...
# 484      484                                     💙토끼상 커스텀🐰 (설참)         11
# 485      485  완전예쁜커마를 2분안에 만들수있다고??? +추천 크리템 추천 [제페토] #제페토 #...         10
# 486      486                                 배드워즈 커스텀으로 버그(?)찾기         10
# 487      487             [제페토 커스텀] 초간단 제페토 귀여운 여아캐 커스텀❣️ (세로영상)          6
# 488      488  순백 커스텀/ 팔레트 필요없음/ 출처 남겨주세요/ 제페토 커스텀/ 예쁜 여캐 커스텀...          3
#
# [489 rows x 3 columns]

# %%
cm = cm.rename(columns={'level_0':'number'})
cm
# Out:
#      number                                              title  viewcount
# 0         0                               🌸벚꽃소녀 커스텀🌸 제페토 얼굴만들기     279000
# 1         1              [제페토 커스텀]💗눈 커스텀 강좌🎀/ zepeto / 제페토 커스텀     138000
# 2         2                        [제페토] 제페토 얼굴만들기! 두기 닮은 커스텀~     115000
# 3         3                            제페토 커스텀 - 도도한 여캐 커스텀 설참     104000
# 4         4                     ⭐기본으로 커스텀⭐ 제페토 얼굴만들기 (+약간의 수정)     102000
# ..      ...                                                ...        ...
# 484     484                                     💙토끼상 커스텀🐰 (설참)         11
# 485     485  완전예쁜커마를 2분안에 만들수있다고??? +추천 크리템 추천 [제페토] #제페토 #...         10
# 486     486                                 배드워즈 커스텀으로 버그(?)찾기         10
# 487     487             [제페토 커스텀] 초간단 제페토 귀여운 여아캐 커스텀❣️ (세로영상)          6
# 488     488  순백 커스텀/ 팔레트 필요없음/ 출처 남겨주세요/ 제페토 커스텀/ 예쁜 여캐 커스텀...          3
#
# [489 rows x 3 columns]
